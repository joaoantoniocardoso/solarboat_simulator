# %%
import sympy as sym

# Symbols
d = sym.Derivative
f = sym.Function
t = sym.symbols("t", constant=False)
pi = sym.symbols("\\pi", constant=True)

sym.init_printing()  # we can use print(latex(...)) to get latex code

# %% [markdown]
# # Propeller equations
# Following the [Actuator Disk Theory](https://web.mit.edu/16.unified/www/FALL/thermodynamics/notes/node86.html)

# %%
# Functions
prop_pi = f("P_{Prop,in}", real=True)(t)
prop_po = f("P_{Prop,out}", real=True)(t)
prop_Q = f("Q_{Prop}", real=True)(t)
prop_T = f("T_{Prop}", real=True)(t)
prop_w = f("\\omega_{Prop}", real=True)(t)
prop_V = f("V_{Prop}", real=True)(t)
prop_J = f("J_{prop}", real=True)(t)
prop_eff = f("\\eta_{Prop}", real=True)(t)
hull_V = f("V_{hull}", real=True)(t)

# Constants
rho, prop_D, prop_A, prop_kT, prop_kQ = sym.symbols(
    "\\rho_{water} D_{disk} A_{disk} k_{Prop\,T} k_{Prop\,Q}", real=True, constant=True, positive=True
)

eq_prop_pi = sym.Eq(
    prop_pi, prop_w * prop_Q
)
eq_prop_po = sym.Eq(
    prop_po, prop_V * prop_T
)
eq_prop_eff_1 = sym.Eq(
    prop_eff, prop_J * prop_kT / prop_kQ
)
eq_prop_eff_2 = sym.Eq(
    prop_eff, prop_po / prop_pi
)
eq_prop_T = sym.Eq(
    prop_T, prop_kT * rho * prop_D**4 * prop_w**2
)
eq_prop_Q = sym.Eq(
    prop_Q, prop_kQ * rho * prop_D**5 * prop_w**2
)
eq_prop_A = sym.Eq(
    prop_A,
    pi * prop_D**2 / 4
)
eq_prop_V = sym.Eq(
    prop_V,
    (hull_V / 2) * (1 + (1 + (prop_T/(prop_A * (rho / 2) * hull_V**2 )))**(1/2) )
).subs({eq_prop_A.lhs: eq_prop_A.rhs})

display(eq_prop_pi, eq_prop_po, eq_prop_eff_1, eq_prop_eff_2, eq_prop_T, eq_prop_Q, eq_prop_A, eq_prop_V)
# Out:
# P_{Prop,in}(t) = Q_{Prop}(t)⋅\omega_{Prop}(t)
# P_{Prop,out}(t) = T_{Prop}(t)⋅V_{Prop}(t)
#                  k_{Prop,T}⋅J_{prop}(t)
# \eta_{Prop}(t) = ──────────────────────
#                        k_{Prop,Q}
#                  P_{Prop,out}(t)
# \eta_{Prop}(t) = ───────────────
#                   P_{Prop,in}(t)
#                       4                                      2
# T_{Prop}(t) = D_{disk} ⋅\rho_{water}⋅k_{Prop,T}⋅\omega_{Prop} (t)
#                       5                                      2
# Q_{Prop}(t) = D_{disk} ⋅\rho_{water}⋅k_{Prop,Q}⋅\omega_{Prop} (t)
#                    2
#            D_{disk} ⋅\pi
# A_{disk} = ─────────────
#                  4
#               ⎛                                             0.5    ⎞
#               ⎜⎛                 8⋅T_{Prop}(t)             ⎞       ⎟
#               ⎜⎜1 + ───────────────────────────────────────⎟    + 1⎟⋅V_{hull}(
#               ⎜⎜            2                          2   ⎟       ⎟
#               ⎝⎝    D_{disk} ⋅\pi⋅\rho_{water}⋅V_{hull} (t)⎠       ⎠
# V_{Prop}(t) = ────────────────────────────────────────────────────────────────
#                                               2
#
#
#
# t)
#
#
# ──

# %%
display(eq_prop_V)

eq_prop_po.subs({eq_prop_V.lhs: eq_prop_V.rhs})
# Out:
#               ⎛                                             0.5    ⎞
#               ⎜⎛                 8⋅T_{Prop}(t)             ⎞       ⎟
#               ⎜⎜1 + ───────────────────────────────────────⎟    + 1⎟⋅V_{hull}(
#               ⎜⎜            2                          2   ⎟       ⎟
#               ⎝⎝    D_{disk} ⋅\pi⋅\rho_{water}⋅V_{hull} (t)⎠       ⎠
# V_{Prop}(t) = ────────────────────────────────────────────────────────────────
#                                               2
#
#
#
# t)
#
#
# ──
#                   ⎛                                             0.5    ⎞
#                   ⎜⎛                 8⋅T_{Prop}(t)             ⎞       ⎟
#                   ⎜⎜1 + ───────────────────────────────────────⎟    + 1⎟⋅T_{Pr
#                   ⎜⎜            2                          2   ⎟       ⎟
#                   ⎝⎝    D_{disk} ⋅\pi⋅\rho_{water}⋅V_{hull} (t)⎠       ⎠
# P_{Prop,out}(t) = ────────────────────────────────────────────────────────────
#                                                         2
#
#
#
# op}(t)⋅V_{hull}(t)
#
#
# ──────────────────

# %%
eq_prop_pi2 = eq_prop_pi.subs({eq_prop_Q.lhs: eq_prop_Q.rhs})
eq_prop_po2 = eq_prop_po.subs({eq_prop_T.lhs: eq_prop_T.rhs}).subs({eq_prop_V.lhs: eq_prop_V.rhs})
display(eq_prop_pi2, eq_prop_po2)
# Out:
#                          5                                      3
# P_{Prop,in}(t) = D_{disk} ⋅\rho_{water}⋅k_{Prop,Q}⋅\omega_{Prop} (t)
#                                                     ⎛
#                           4                         ⎜⎛                 8⋅T_{Pr
#                   D_{disk} ⋅\rho_{water}⋅k_{Prop,T}⋅⎜⎜1 + ────────────────────
#                                                     ⎜⎜            2
#                                                     ⎝⎝    D_{disk} ⋅\pi⋅\rho_{
# P_{Prop,out}(t) = ────────────────────────────────────────────────────────────
#                                                                             2
#
#                     0.5    ⎞
# op}(t)             ⎞       ⎟                          2
# ───────────────────⎟    + 1⎟⋅V_{hull}(t)⋅\omega_{Prop} (t)
#                2   ⎟       ⎟
# water}⋅V_{hull} (t)⎠       ⎠
# ──────────────────────────────────────────────────────────

# %% [markdown]
# # Hull equations

# %%
# Functions
# hull_V = f("V_{Hull}")(t) # Already defined
hull_R = f("R_{Hull}")(t)

# Constants
hull_k, hull_S, hull_C = sym.symbols(
    "k_{Hull} C_{f} S_{w}", real=True, constant=True, positive=True
)

eq_hull_R_full = sym.Eq(
    hull_R,
    (1/2) * hull_C * rho * hull_S * hull_V**2
)

hull_k_eq = sym.Eq(
    hull_k,
    (1/2) * hull_C * rho * hull_S
)

eq_hull_R_simple = eq_hull_R_full.subs({hull_k_eq.rhs: hull_k_eq.lhs})

eq_hull_R = eq_hull_R_full

display(eq_hull_R_full, hull_k_eq, eq_hull_R_simple)
# Out:
#                                                    2
# R_{Hull}(t) = 0.5⋅C_{f}⋅S_{w}⋅\rho_{water}⋅V_{hull} (t)
# k_{Hull} = 0.5⋅C_{f}⋅S_{w}⋅\rho_{water}
#                                2
# R_{Hull}(t) = k_{Hull}⋅V_{hull} (t)

# %% [markdown]
# # Propeller-Hull coupling

# %%
eq_prop_T2 = sym.Eq(
    prop_T,
    hull_R
)
display(eq_prop_T2)

eq_prop_T2 = sym.Eq(
    prop_T,
    eq_hull_R_full.rhs
)
display(eq_prop_T2)

eq_hull_V = sym.Eq(
    hull_V,
    sym.solve(
        eq_prop_T2,
        hull_V**2
    )[0]
)
display(eq_hull_V)

display(eq_prop_T)
eq_hull_V = eq_hull_V.subs({eq_prop_T.lhs: eq_prop_T.rhs})
display(eq_hull_V)
# Out:
# T_{Prop}(t) = R_{Hull}(t)
#                                                    2
# T_{Prop}(t) = 0.5⋅C_{f}⋅S_{w}⋅\rho_{water}⋅V_{hull} (t)
#                   2.0⋅T_{Prop}(t)
# V_{hull}(t) = ────────────────────────
#               C_{f}⋅S_{w}⋅\rho_{water}
#                       4                                      2
# T_{Prop}(t) = D_{disk} ⋅\rho_{water}⋅k_{Prop,T}⋅\omega_{Prop} (t)
#                           4                         2
#               2.0⋅D_{disk} ⋅k_{Prop,T}⋅\omega_{Prop} (t)
# V_{hull}(t) = ──────────────────────────────────────────
#                              C_{f}⋅S_{w}

# %%
display(eq_prop_po2, eq_prop_T2)

eq_prop_po3 = eq_prop_po2.subs({
    eq_prop_T2.lhs: eq_prop_T2.rhs,
    eq_hull_V.lhs: eq_hull_V.rhs,
})
display(eq_prop_po3)
# Out:
#                                                     ⎛
#                           4                         ⎜⎛                 8⋅T_{Pr
#                   D_{disk} ⋅\rho_{water}⋅k_{Prop,T}⋅⎜⎜1 + ────────────────────
#                                                     ⎜⎜            2
#                                                     ⎝⎝    D_{disk} ⋅\pi⋅\rho_{
# P_{Prop,out}(t) = ────────────────────────────────────────────────────────────
#                                                                             2
#
#                     0.5    ⎞
# op}(t)             ⎞       ⎟                          2
# ───────────────────⎟    + 1⎟⋅V_{hull}(t)⋅\omega_{Prop} (t)
#                2   ⎟       ⎟
# water}⋅V_{hull} (t)⎠       ⎠
# ──────────────────────────────────────────────────────────
#                                                    2
# T_{Prop}(t) = 0.5⋅C_{f}⋅S_{w}⋅\rho_{water}⋅V_{hull} (t)
#                                                          ⎛
#                               8                        2 ⎜    ⎛ C_{f}⋅S_{w}
#                   1.0⋅D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜2.0⋅⎜───────────── +
#                                                          ⎜    ⎜        2
#                                                          ⎝    ⎝D_{disk} ⋅\pi
# P_{Prop,out}(t) = ────────────────────────────────────────────────────────────
#                                                           C_{f}⋅S_{w}
#
#       0.5    ⎞
#      ⎞       ⎟              4
#  0.25⎟    + 1⎟⋅\omega_{Prop} (t)
#      ⎟       ⎟
#      ⎠       ⎠
# ────────────────────────────────

# %%
display(eq_prop_eff_2)

eq = sym.Eq(
    prop_po,
    sym.solve(
        eq_prop_eff_2,
        prop_po,
    )[0],
)
display(eq)

eq = eq_prop_po3.subs(
    eq_prop_po3.lhs,
    eq.rhs,
)
display(eq)

eq_prop_pi3 = sym.Eq(
    prop_pi,
    sym.solve(
        eq,
        prop_pi,
    )[0]
)
display(eq_prop_pi3)
# Out:
#                  P_{Prop,out}(t)
# \eta_{Prop}(t) = ───────────────
#                   P_{Prop,in}(t)
# P_{Prop,out}(t) = P_{Prop,in}(t)⋅\eta_{Prop}(t)
#                                                                        ⎛
#                                             8                        2 ⎜    ⎛
#                                 1.0⋅D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜2.0⋅⎜─
#                                                                        ⎜    ⎜
#                                                                        ⎝    ⎝D
# P_{Prop,in}(t)⋅\eta_{Prop}(t) = ──────────────────────────────────────────────
#                                                                         C_{f}⋅
#
#                     0.5    ⎞
# C_{f}⋅S_{w}        ⎞       ⎟              4
# ──────────── + 0.25⎟    + 1⎟⋅\omega_{Prop} (t)
#        2           ⎟       ⎟
# _{disk} ⋅\pi       ⎠       ⎠
# ──────────────────────────────────────────────
# S_{w}
#                                                     ⎛                _________
#                                                     ⎜               ╱
#                          7                        2 ⎜              ╱  4.0⋅C_{f
#                  D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ────────
#                                                     ⎝           ╲╱
# P_{Prop,in}(t) = ─────────────────────────────────────────────────────────────
#                                                         C_{f}⋅S_{w}⋅\eta_{Prop
#
# ________________________⎞
#                   2     ⎟
# }⋅S_{w} + D_{disk} ⋅\pi ⎟              4
# ─────────────────────── ⎟⋅\omega_{Prop} (t)
#       \pi               ⎠
# ───────────────────────────────────────────
# }(t)

# %% [markdown]
# # Transmission equations

# %%
# Functions
trans_Qi = f("Q_{Trans, in}", real=True)(t)
trans_Qo = f("Q_{Trans, out}", real=True)(t)
trans_wi = f("\\omega_{Trans, in}", real=True)(t)
trans_wo = f("\\omega_{Trans, out}", real=True)(t)
trans_pi = f("P_{Trans, in}", real=True)(t)
trans_po = f("P_{Trans, out}", real=True)(t)

# Constants
trans_K, trans_eff = sym.symbols(
    "k_{Trans} \\eta_{Trans}", real=True, constant=True, positive=True
)

eq_trans_pi = sym.Eq(
    trans_pi,
    trans_wi * trans_Qi
)
eq_trans_po = sym.Eq(
    trans_po,
    trans_wo * trans_Qo
)

eq_trans_wo = sym.Eq(
    trans_wo,
    trans_wi / trans_K
)
eq_trans_po2 = sym.Eq(
    trans_po,
    trans_eff * trans_pi
)

display(eq_trans_pi, eq_trans_po, eq_trans_wo, eq_trans_po2)
# Out:
# P_{Trans, in}(t) = Q_{Trans, in}(t)⋅\omega_{Trans, in}(t)
# P_{Trans, out}(t) = Q_{Trans, out}(t)⋅\omega_{Trans, out}(t)
#                          \omega_{Trans, in}(t)
# \omega_{Trans, out}(t) = ─────────────────────
#                                k_{Trans}
# P_{Trans, out}(t) = \eta_{Trans}⋅P_{Trans, in}(t)

# %% [markdown]
# # Transmission-Propeller coupling

# %%
eq_prop_w = sym.Eq(
    prop_w, trans_wo
)
display(eq_prop_w)

eq_prop_pi4 = sym.Eq(
    prop_pi, trans_po
)
display(eq_prop_pi4)

eq_prop_pi4 = eq_prop_pi4.subs({eq_trans_po2.lhs: eq_trans_po2.rhs})
display(eq_prop_pi4)

eq_prop_w = eq_prop_w.subs({eq_trans_wo.lhs: eq_trans_wo.rhs})
display(eq_prop_w)
# Out:
# \omega_{Prop}(t) = \omega_{Trans, out}(t)
# P_{Prop,in}(t) = P_{Trans, out}(t)
# P_{Prop,in}(t) = \eta_{Trans}⋅P_{Trans, in}(t)
#                    \omega_{Trans, in}(t)
# \omega_{Prop}(t) = ─────────────────────
#                          k_{Trans}

# %%
display(eq_prop_pi3)

eq = eq_prop_pi3.subs({
    eq_prop_pi4.lhs: eq_prop_pi4.rhs,
    eq_prop_w.lhs: eq_prop_w.rhs,
})
display(eq)

eq_trans_pi2 = sym.Eq(
    trans_pi,
    sym.solve(eq, trans_pi)[0]
)
display(eq_trans_pi2)
# Out:
#                                                     ⎛                _________
#                                                     ⎜               ╱
#                          7                        2 ⎜              ╱  4.0⋅C_{f
#                  D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ────────
#                                                     ⎝           ╲╱
# P_{Prop,in}(t) = ─────────────────────────────────────────────────────────────
#                                                         C_{f}⋅S_{w}⋅\eta_{Prop
#
# ________________________⎞
#                   2     ⎟
# }⋅S_{w} + D_{disk} ⋅\pi ⎟              4
# ─────────────────────── ⎟⋅\omega_{Prop} (t)
#       \pi               ⎠
# ───────────────────────────────────────────
# }(t)
#                                                                    ⎛
#                                                                    ⎜
#                                         7                        2 ⎜
#                                 D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +
#                                                                    ⎝
# \eta_{Trans}⋅P_{Trans, in}(t) = ──────────────────────────────────────────────
#
#                                                                     C_{f}⋅S_{w
#
#       _________________________________⎞
#      ╱                           2     ⎟
#     ╱  4.0⋅C_{f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   4
#    ╱   ─────────────────────────────── ⎟⋅\omega_{Trans, in} (t)
#  ╲╱                  \pi               ⎠
# ───────────────────────────────────────────────────────────────
#            4
# }⋅k_{Trans} ⋅\eta_{Prop}(t)
#                                                       ⎛                _______
#                                                       ⎜               ╱
#                            7                        2 ⎜              ╱  4.0⋅C_
#                    D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ──────
#                                                       ⎝           ╲╱
# P_{Trans, in}(t) = ───────────────────────────────────────────────────────────
#
#                                                  C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{T
#
# __________________________⎞
#                     2     ⎟
# {f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   4
# ───────────────────────── ⎟⋅\omega_{Trans, in} (t)
#         \pi               ⎠
# ──────────────────────────────────────────────────
#      4
# rans} ⋅\eta_{Prop}(t)

# %% [markdown]
# # Motor equations

# %%
# System Functions
motor_i = f("I_{Motor}", real=True)(t)
motor_v = f("V_{Motor}", real=True)(t)
motor_w = f("\\omega_{Motor}", real=True)(t)
motor_ang = f("\\theta_{Motor}", real=True)(t)
motor_load_Q = f("Q_{Motor Load}", real=True)(t)

# Power Functions
motor_pi = f("P_{Motor,in}", real=True)(t)
motor_po = f("P_{Motor,out}", real=True)(t)
motor_pl = f("P_{Motor,loss}", real=True)(t)
motor_eff = f("\\eta_{Motor}", real=True)(t)

# Constants
R_A, L_A, K_T, K_V, J_M, B_M = sym.symbols(
    "R_A L_A K_T K_V J_M B_M", real=True, constant=True, positive=True
)

# System Equations
eq_motor_didt = sym.Eq(
    d(motor_i, t), -(R_A / L_A) * motor_i - (K_T / L_A) * motor_w + (1 / L_A) * motor_v
)
eq_motor_dwdt = sym.Eq(
    d(motor_w, t), (K_T / J_M) * motor_i - (B_M / J_M) * motor_w - (1 / J_M) * motor_load_Q
)
eq_motor_dangdt = sym.Eq(d(motor_ang, t), motor_w)

# Power Equations
eq_motor_pi = sym.Eq(motor_pi, motor_i * motor_v)
eq_motor_po = sym.Eq(motor_po, motor_w * motor_load_Q)
eq_motor_pl = sym.Eq(motor_pl, R_A * motor_i**2 + B_M * motor_w**2)
eq_motor_po2 = sym.Eq(motor_po, motor_eff * motor_pi)

display(eq_motor_didt, eq_motor_dwdt, eq_motor_dangdt, eq_motor_pi, eq_motor_po, eq_motor_pl, eq_motor_po2)
# Out:
# d                    K_T⋅\omega_{Motor}(t)   R_A⋅I_{Motor}(t)   V_{Motor}(t)
# ──(I_{Motor}(t)) = - ───────────────────── - ──────────────── + ────────────
# dt                            L_A                  L_A              L_A
# d                         B_M⋅\omega_{Motor}(t)   K_T⋅I_{Motor}(t)   Q_{Motor
# ──(\omega_{Motor}(t)) = - ───────────────────── + ──────────────── - ─────────
# dt                                 J_M                  J_M                 J_
#
# Load}(t)
# ────────
# M
# d
# ──(\theta_{Motor}(t)) = \omega_{Motor}(t)
# dt
# P_{Motor,in}(t) = I_{Motor}(t)⋅V_{Motor}(t)
# P_{Motor,out}(t) = Q_{Motor Load}(t)⋅\omega_{Motor}(t)
#                                       2                   2
# P_{Motor,loss}(t) = B_M⋅\omega_{Motor} (t) + R_A⋅I_{Motor} (t)
# P_{Motor,out}(t) = P_{Motor,in}(t)⋅\eta_{Motor}(t)

# %% [markdown]
# # Motor-Transmission Coupling

# %%
eq_trans_wi = sym.Eq(
    trans_wi, motor_w
)
display(eq_trans_wi)

eq_trans_pi3 = sym.Eq(
    trans_pi, motor_po
)
display(eq_trans_pi3)

eq_trans_qi = sym.Eq(
    trans_Qi, motor_load_Q
)
display(eq_trans_qi)

eq_trans_pi3 = eq_trans_pi3.subs({eq_motor_po2.lhs: eq_motor_po2.rhs})
display(eq_trans_pi3)
# Out:
# \omega_{Trans, in}(t) = \omega_{Motor}(t)
# P_{Trans, in}(t) = P_{Motor,out}(t)
# Q_{Trans, in}(t) = Q_{Motor Load}(t)
# P_{Trans, in}(t) = P_{Motor,in}(t)⋅\eta_{Motor}(t)

# %%
display(eq_trans_pi2)

eq = eq_trans_pi2.subs({
    eq_trans_pi3.lhs: eq_trans_pi3.rhs,
    eq_trans_wi.lhs: eq_trans_wi.rhs,
})
display(eq)

eq_motor_pi2 = sym.Eq(
    motor_pi,
    sym.solve(eq, motor_pi)[0]
)
display(eq_motor_pi2)
# Out:
#                                                       ⎛                _______
#                                                       ⎜               ╱
#                            7                        2 ⎜              ╱  4.0⋅C_
#                    D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ──────
#                                                       ⎝           ╲╱
# P_{Trans, in}(t) = ───────────────────────────────────────────────────────────
#
#                                                  C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{T
#
# __________________________⎞
#                     2     ⎟
# {f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   4
# ───────────────────────── ⎟⋅\omega_{Trans, in} (t)
#         \pi               ⎠
# ──────────────────────────────────────────────────
#      4
# rans} ⋅\eta_{Prop}(t)
#                                                                      ⎛
#                                                                      ⎜
#                                           7                        2 ⎜
#                                   D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk}
#                                                                      ⎝
# P_{Motor,in}(t)⋅\eta_{Motor}(t) = ────────────────────────────────────────────
#
#                                                               C_{f}⋅S_{w}⋅\eta
#
#         _________________________________⎞
#        ╱                           2     ⎟
#       ╱  4.0⋅C_{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               4
#  +   ╱   ─────────────────────────────── ⎟⋅\omega_{Motor} (t)
#    ╲╱                  \pi               ⎠
# ─────────────────────────────────────────────────────────────
#                   4
# _{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t)
#                                                      ⎛                ________
#                                                      ⎜               ╱
#                           7                        2 ⎜              ╱  4.0⋅C_{
#                   D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ───────
#                                                      ⎝           ╲╱
# P_{Motor,in}(t) = ────────────────────────────────────────────────────────────
#                                                                         4
#                                       C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta
#
# _________________________⎞
#                    2     ⎟
# f}⋅S_{w} + D_{disk} ⋅\pi ⎟               4
# ──────────────────────── ⎟⋅\omega_{Motor} (t)
#        \pi               ⎠
# ─────────────────────────────────────────────
#
# _{Motor}(t)⋅\eta_{Prop}(t)

# %%
display(eq_trans_pi2)

eq = eq_trans_pi2.subs({
    eq_trans_pi.lhs: eq_trans_pi.rhs
})
display(eq)

eq = sym.Eq(
    trans_Qi,
    sym.solve(eq, trans_Qi)[0]
)
display(eq)

eq_motor_load_Q = eq.subs({
    eq_trans_qi.lhs: eq_trans_qi.rhs,
    eq_trans_wi.lhs: eq_trans_wi.rhs
})
display(eq_motor_load_Q)
# Out:
#                                                       ⎛                _______
#                                                       ⎜               ╱
#                            7                        2 ⎜              ╱  4.0⋅C_
#                    D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ──────
#                                                       ⎝           ╲╱
# P_{Trans, in}(t) = ───────────────────────────────────────────────────────────
#
#                                                  C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{T
#
# __________________________⎞
#                     2     ⎟
# {f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   4
# ───────────────────────── ⎟⋅\omega_{Trans, in} (t)
#         \pi               ⎠
# ──────────────────────────────────────────────────
#      4
# rans} ⋅\eta_{Prop}(t)
#                                                                             ⎛
#                                                                             ⎜
#                                                  7                        2 ⎜
#                                          D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D
#                                                                             ⎝
# Q_{Trans, in}(t)⋅\omega_{Trans, in}(t) = ─────────────────────────────────────
#
#                                                                        C_{f}⋅S
#
#                _________________________________⎞
#               ╱                           2     ⎟
#              ╱  4.0⋅C_{f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   4
# _{disk} +   ╱   ─────────────────────────────── ⎟⋅\omega_{Trans, in} (t)
#           ╲╱                  \pi               ⎠
# ────────────────────────────────────────────────────────────────────────
#                            4
# _{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t)
#                                                       ⎛                _______
#                                                       ⎜               ╱
#                            7                        2 ⎜              ╱  4.0⋅C_
#                    D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ──────
#                                                       ⎝           ╲╱
# Q_{Trans, in}(t) = ───────────────────────────────────────────────────────────
#
#                                                  C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{T
#
# __________________________⎞
#                     2     ⎟
# {f}⋅S_{w} + D_{disk} ⋅\pi ⎟                   3
# ───────────────────────── ⎟⋅\omega_{Trans, in} (t)
#         \pi               ⎠
# ──────────────────────────────────────────────────
#      4
# rans} ⋅\eta_{Prop}(t)
#                                                        ⎛                ______
#                                                        ⎜               ╱
#                             7                        2 ⎜              ╱  4.0⋅C
#                     D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ─────
#                                                        ⎝           ╲╱
# Q_{Motor Load}(t) = ──────────────────────────────────────────────────────────
#
#                                                 C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Tr
#
# ___________________________⎞
#                      2     ⎟
# _{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               3
# ────────────────────────── ⎟⋅\omega_{Motor} (t)
#          \pi               ⎠
# ───────────────────────────────────────────────
#     4
# ans} ⋅\eta_{Prop}(t)

# %%
eq_motor_dwdt2 = eq_motor_dwdt.subs({eq_motor_load_Q.lhs: eq_motor_load_Q.rhs}).expand()
display(eq_motor_dwdt2)
eq_motor_didt
display(eq_motor_didt)
# Out:
#
#
#                                                                              8
# d                         B_M⋅\omega_{Motor}(t)   K_T⋅I_{Motor}(t)   D_{disk}
# ──(\omega_{Motor}(t)) = - ───────────────────── + ──────────────── - ─────────
# dt                                 J_M                  J_M
#                                                                      C_{f}⋅J_M
#
#
#                                                             7
#                         2               3       2.0⋅D_{disk} ⋅\rho_{water}⋅k_{
# ⋅\rho_{water}⋅k_{Prop,T} ⋅\omega_{Motor} (t)
# ───────────────────────────────────────────── - ──────────────────────────────
#                              4
# ⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t)                      C_{f}⋅J_M⋅S
#
#              ______________________________
#        2    ╱ C_{f}⋅S_{w}                2                3
# Prop,T} ⋅  ╱  ─────────── + 0.25⋅D_{disk}  ⋅\omega_{Motor} (t)
#          ╲╱       \pi
# ──────────────────────────────────────────────────────────────
#                            4
# _{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t)
# d                    K_T⋅\omega_{Motor}(t)   R_A⋅I_{Motor}(t)   V_{Motor}(t)
# ──(I_{Motor}(t)) = - ───────────────────── - ──────────────── + ────────────
# dt                            L_A                  L_A              L_A

# %% [markdown]
# # ESC equations

# %%
# System Functions
esc_D = f("D_{ESC}", real=True)(t)

# Power Functions
esc_pi = f("P_{ESC,in}", real=True)(t)
esc_po = f("P_{ESC,out}", real=True)(t)
esc_vi = f("V_{ESC,in}", real=True)(t)
esc_vo = f("V_{ESC,out}", real=True)(t)
esc_ii = f("I_{ESC,in}", real=True)(t)
esc_io = f("I_{ESC,out}", real=True)(t)
esc_eff = f("\\eta_{ESC}", real=True)(t)

# System Equations
eq_esc_vo = sym.Eq(esc_vo, esc_vi * esc_D)

# Power Equations
eq_esc_pi = sym.Eq(esc_pi, esc_ii * esc_vi)
eq_esc_po = sym.Eq(esc_po, esc_io * esc_vo)
eq_esc_po2 = sym.Eq(esc_po, esc_eff * esc_pi)

display(eq_esc_vo, eq_esc_pi, eq_esc_po, eq_esc_po2)
# Out:
# V_{ESC,out}(t) = D_{ESC}(t)⋅V_{ESC,in}(t)
# P_{ESC,in}(t) = I_{ESC,in}(t)⋅V_{ESC,in}(t)
# P_{ESC,out}(t) = I_{ESC,out}(t)⋅V_{ESC,out}(t)
# P_{ESC,out}(t) = P_{ESC,in}(t)⋅\eta_{ESC}(t)

# %% [markdown]
# # ESC-Motor Coupling

# %%
eq_motor_pi3 = sym.Eq(motor_pi, esc_po)
display(eq_motor_pi3)
eq_motor_pi3 = eq_motor_pi3.subs({eq_esc_po2.lhs: eq_esc_po2.rhs})
display(eq_motor_pi3)

eq_motor_v = sym.Eq(motor_v, esc_vo)
display(eq_motor_v)
eq_motor_v = eq_motor_v.subs({eq_esc_vo.lhs: eq_esc_vo.rhs})
display(eq_motor_v)
# Out:
# P_{Motor,in}(t) = P_{ESC,out}(t)
# P_{Motor,in}(t) = P_{ESC,in}(t)⋅\eta_{ESC}(t)
# V_{Motor}(t) = V_{ESC,out}(t)
# V_{Motor}(t) = D_{ESC}(t)⋅V_{ESC,in}(t)

# %%
display(eq_motor_pi2)

eq = eq_motor_pi2.subs({
    eq_motor_pi3.lhs: eq_motor_pi3.rhs,
    eq_trans_wi.lhs: eq_trans_wi.rhs,
})
display(eq)

eq_esc_pi2 = sym.Eq(
    esc_pi,
    sym.solve(eq, esc_pi)[0]
)
display(eq_esc_pi2)
# Out:
#                                                      ⎛                ________
#                                                      ⎜               ╱
#                           7                        2 ⎜              ╱  4.0⋅C_{
#                   D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ───────
#                                                      ⎝           ╲╱
# P_{Motor,in}(t) = ────────────────────────────────────────────────────────────
#                                                                         4
#                                       C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta
#
# _________________________⎞
#                    2     ⎟
# f}⋅S_{w} + D_{disk} ⋅\pi ⎟               4
# ──────────────────────── ⎟⋅\omega_{Motor} (t)
#        \pi               ⎠
# ─────────────────────────────────────────────
#
# _{Motor}(t)⋅\eta_{Prop}(t)
#                                                                  ⎛
#                                                                  ⎜
#                                       7                        2 ⎜
#                               D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +
#                                                                  ⎝           ╲
# P_{ESC,in}(t)⋅\eta_{ESC}(t) = ────────────────────────────────────────────────
#
#                                                   C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{
#
#     _________________________________⎞
#    ╱                           2     ⎟
#   ╱  4.0⋅C_{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               4
#  ╱   ─────────────────────────────── ⎟⋅\omega_{Motor} (t)
# ╱                  \pi               ⎠
# ─────────────────────────────────────────────────────────
#       4
# Trans} ⋅\eta_{Motor}(t)⋅\eta_{Prop}(t)
#                                                    ⎛                __________
#                                                    ⎜               ╱
#                         7                        2 ⎜              ╱  4.0⋅C_{f}
#                 D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ─────────
#                                                    ⎝           ╲╱
# P_{ESC,in}(t) = ──────────────────────────────────────────────────────────────
#                                                                4
#                              C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{ESC}(t)
#
# _______________________⎞
#                  2     ⎟
# ⋅S_{w} + D_{disk} ⋅\pi ⎟               4
# ────────────────────── ⎟⋅\omega_{Motor} (t)
#      \pi               ⎠
# ───────────────────────────────────────────
#
# ⋅\eta_{Motor}(t)⋅\eta_{Prop}(t)

# %% [markdown]
# # Solving
# We just need to solve the motor system for $W_{Motor}$ now

# %%
display(eq_motor_load_Q)
display(eq_motor_dwdt)
display(eq_motor_didt)
# Out:
#                                                        ⎛                ______
#                                                        ⎜               ╱
#                             7                        2 ⎜              ╱  4.0⋅C
#                     D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ─────
#                                                        ⎝           ╲╱
# Q_{Motor Load}(t) = ──────────────────────────────────────────────────────────
#
#                                                 C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Tr
#
# ___________________________⎞
#                      2     ⎟
# _{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               3
# ────────────────────────── ⎟⋅\omega_{Motor} (t)
#          \pi               ⎠
# ───────────────────────────────────────────────
#     4
# ans} ⋅\eta_{Prop}(t)
# d                         B_M⋅\omega_{Motor}(t)   K_T⋅I_{Motor}(t)   Q_{Motor
# ──(\omega_{Motor}(t)) = - ───────────────────── + ──────────────── - ─────────
# dt                                 J_M                  J_M                 J_
#
# Load}(t)
# ────────
# M
# d                    K_T⋅\omega_{Motor}(t)   R_A⋅I_{Motor}(t)   V_{Motor}(t)
# ──(I_{Motor}(t)) = - ───────────────────── - ──────────────── + ────────────
# dt                            L_A                  L_A              L_A

# %%
print(sym.latex(eq_motor_load_Q))
print(sym.latex(eq_motor_dwdt))
print(sym.latex(eq_motor_didt))
# Out:
# Q_{Motor Load}{\left(t \right)} = \frac{D_{disk}^{7} \rho_{water} k_{Prop,T}^{2} \left(D_{disk} + \sqrt{\frac{4.0 C_{f} S_{w} + D_{disk}^{2} \pi}{\pi}}\right) \omega_{Motor}^{3}{\left(t \right)}}{C_{f} S_{w} \eta_{Trans} k_{Trans}^{4} \eta_{Prop}{\left(t \right)}}
# \frac{d}{d t} \omega_{Motor}{\left(t \right)} = - \frac{B_{M} \omega_{Motor}{\left(t \right)}}{J_{M}} + \frac{K_{T} I_{Motor}{\left(t \right)}}{J_{M}} - \frac{Q_{Motor Load}{\left(t \right)}}{J_{M}}
# \frac{d}{d t} I_{Motor}{\left(t \right)} = - \frac{K_{T} \omega_{Motor}{\left(t \right)}}{L_{A}} - \frac{R_{A} I_{Motor}{\left(t \right)}}{L_{A}} + \frac{V_{Motor}{\left(t \right)}}{L_{A}}

# %% [markdown]
# ## Steady-state

# %%
display(eq_motor_load_Q)

eq_motor_dwdt_ss = eq_motor_dwdt.subs({eq_motor_dwdt.lhs: 0})
display(eq_motor_dwdt_ss)

eq_motor_didt_ss = eq_motor_didt.subs({eq_motor_didt.lhs: 0})
display(eq_motor_didt_ss)
# Out:
#                                                        ⎛                ______
#                                                        ⎜               ╱
#                             7                        2 ⎜              ╱  4.0⋅C
#                     D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ─────
#                                                        ⎝           ╲╱
# Q_{Motor Load}(t) = ──────────────────────────────────────────────────────────
#
#                                                 C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Tr
#
# ___________________________⎞
#                      2     ⎟
# _{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               3
# ────────────────────────── ⎟⋅\omega_{Motor} (t)
#          \pi               ⎠
# ───────────────────────────────────────────────
#     4
# ans} ⋅\eta_{Prop}(t)
#       B_M⋅\omega_{Motor}(t)   K_T⋅I_{Motor}(t)   Q_{Motor Load}(t)
# 0 = - ───────────────────── + ──────────────── - ─────────────────
#                J_M                  J_M                 J_M
#       K_T⋅\omega_{Motor}(t)   R_A⋅I_{Motor}(t)   V_{Motor}(t)
# 0 = - ───────────────────── - ──────────────── + ────────────
#                L_A                  L_A              L_A

# %%
display(eq_motor_didt_ss)

eq_motor_i_ss = sym.Eq(
    motor_i,
    sym.solve(eq_motor_didt_ss, motor_i)[0]
)
display(eq_motor_i_ss)

eq_motor_i_ss = eq_motor_i_ss.subs({eq_motor_v.lhs: eq_motor_v.rhs})
display(eq_motor_i_ss)
# Out:
#       K_T⋅\omega_{Motor}(t)   R_A⋅I_{Motor}(t)   V_{Motor}(t)
# 0 = - ───────────────────── - ──────────────── + ────────────
#                L_A                  L_A              L_A
#                -K_T⋅\omega_{Motor}(t) + V_{Motor}(t)
# I_{Motor}(t) = ─────────────────────────────────────
#                                 R_A
#                -K_T⋅\omega_{Motor}(t) + D_{ESC}(t)⋅V_{ESC,in}(t)
# I_{Motor}(t) = ─────────────────────────────────────────────────
#                                       R_A

# %%
eq = eq_motor_dwdt_ss.subs({
    eq_motor_i_ss.lhs: eq_motor_i_ss.rhs,
})
display(eq)

eq = sym.Eq(
    eq.lhs,
    sym.collect(eq.rhs.expand(), motor_w)
)
display(eq)


eq_motor_w_ss = [
    sym.Eq(
        motor_w,
        res
    ) for res in sym.solve(eq, motor_w)
]
[display(eq) for eq in eq_motor_w_ss]

eq_motor_w_ss = eq_motor_w_ss[0]
# Out:
#       B_M⋅\omega_{Motor}(t)   K_T⋅(-K_T⋅\omega_{Motor}(t) + D_{ESC}(t)⋅V_{ESC,
# 0 = - ───────────────────── + ────────────────────────────────────────────────
#                J_M                                    J_M⋅R_A
#
# in}(t))   Q_{Motor Load}(t)
# ─────── - ─────────────────
#                  J_M
#     ⎛             2 ⎞
#     ⎜  B_M     K_T  ⎟                     K_T⋅D_{ESC}(t)⋅V_{ESC,in}(t)   Q_{Mo
# 0 = ⎜- ─── - ───────⎟⋅\omega_{Motor}(t) + ──────────────────────────── - ─────
#     ⎝  J_M   J_M⋅R_A⎠                               J_M⋅R_A
#
#
# tor Load}(t)
# ────────────
#   J_M
#                     K_T⋅D_{ESC}(t)⋅V_{ESC,in}(t) - R_A⋅Q_{Motor Load}(t)
# \omega_{Motor}(t) = ────────────────────────────────────────────────────
#                                                     2
#                                        B_M⋅R_A + K_T

# %% [markdown]
# ### Steady-State equations

# %%
display(eq_motor_load_Q)
display(eq_motor_i_ss.expand())
display(eq_motor_w_ss.expand())
# Out:
#                                                        ⎛                ______
#                                                        ⎜               ╱
#                             7                        2 ⎜              ╱  4.0⋅C
#                     D_{disk} ⋅\rho_{water}⋅k_{Prop,T} ⋅⎜D_{disk} +   ╱   ─────
#                                                        ⎝           ╲╱
# Q_{Motor Load}(t) = ──────────────────────────────────────────────────────────
#
#                                                 C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Tr
#
# ___________________________⎞
#                      2     ⎟
# _{f}⋅S_{w} + D_{disk} ⋅\pi ⎟               3
# ────────────────────────── ⎟⋅\omega_{Motor} (t)
#          \pi               ⎠
# ───────────────────────────────────────────────
#     4
# ans} ⋅\eta_{Prop}(t)
#                  K_T⋅\omega_{Motor}(t)   D_{ESC}(t)⋅V_{ESC,in}(t)
# I_{Motor}(t) = - ───────────────────── + ────────────────────────
#                           R_A                      R_A
#                     K_T⋅D_{ESC}(t)⋅V_{ESC,in}(t)   R_A⋅Q_{Motor Load}(t)
# \omega_{Motor}(t) = ──────────────────────────── - ─────────────────────
#                                         2                           2
#                            B_M⋅R_A + K_T               B_M⋅R_A + K_T

# %%
load_k = sym.Symbol("k_{load}", real=True, constant=True, positive=True)
eq = eq_motor_w_ss.subs({motor_load_Q: load_k*motor_w**3}).expand()
eq = eq_motor_w_ss.subs({eq_motor_load_Q.lhs: eq_motor_load_Q.rhs}).expand()
display(eq)

# This is like x(t) = a*y(t) - b*(x(t))**3, which has exact solutions:
eq_motor_w_ss2 = [
    sym.Eq(
        motor_w,
        res.simplify()
    ) for res in sym.solve(eq, motor_w)
]
[display(eq) for eq in eq_motor_w_ss2]

eq_motor_w_ss2 = eq_motor_w_ss2[2]
# Out:
#
#
#                                                            8
#                                                    D_{disk} ⋅R_A⋅\rho_{water}⋅
# \omega_{Motor}(t) = - ────────────────────────────────────────────────────────
#                                                                 4
#                       B_M⋅C_{f}⋅R_A⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(
#
#
#
#           2               3                                              2.0⋅D
# k_{Prop,T} ⋅\omega_{Motor} (t)
# ──────────────────────────────────────────────────────────── - ───────────────
#               2                             4
# t) + C_{f}⋅K_T ⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t)   B_M⋅C_{f}⋅R_A⋅S
#
#                                           ______________________________
#        7                            2    ╱ C_{f}⋅S_{w}                2
# _{disk} ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅  ╱  ─────────── + 0.25⋅D_{disk}  ⋅\omeg
#                                       ╲╱       \pi
# ──────────────────────────────────────────────────────────────────────────────
#                            4                           2
# _{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t) + C_{f}⋅K_T ⋅S_{w}⋅\eta_{Trans}⋅k_
#
#
#          3
# a_{Motor} (t)
#                           K_T⋅D_{ESC}(t)⋅V_{ESC,in}(t)
# ─────────────────────── + ────────────────────────────
#        4                                      2
# {Trans} ⋅\eta_{Prop}(t)          B_M⋅R_A + K_T
#
#
#
#
#
#
#                                                                           4
#                     - 0.419973683298291⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅(0
#
#
#
#
#
#
# \omega_{Motor}(t) = ──────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                  14/3    2/3
#                                                          D_{disk}    ⋅R_A   ⋅\
#
#
#
#
#
#
#
#
#
#
#
#
#                           ⎛             2⎞
# .5 - 0.866025403784439⋅ⅈ)⋅⎝B_M⋅R_A + K_T ⎠⋅\eta_{Prop}(t) + 0.7937005259841⋅D_
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  _____________________________
#                                                 ╱
#                                                ╱
#                                               ╱
#                                              ╱
#                                             ╱
#                                            ╱
#                                           ╱       - C_{f}⋅K_T⋅S_{w}⋅\eta_{Tran
#                                          ╱
#                                         ╱
#                                        ╱
#                                       ╱
#                                      ╱
#            2/3           4/3        ╱
# rho_{water}   ⋅k_{Prop,T}   ⋅      ╱              ────────────────────────────
#                                   ╱
#                                  ╱
#                                 ╱
#                              3 ╱
#                              ╲╱
#
#
#
#
#
#                                                                ⎛
#                                                                ⎜
#       7/3 3 _____ 3 ______________                             ⎜
# {disk}   ⋅╲╱ R_A ⋅╲╱ \rho_{water} ⋅(0.5 + 0.866025403784439⋅ⅈ)⋅⎜D_{disk} + 2.0
#                                                                ⎝
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#
#
#
#
#             4                                                    1.0         -
# s}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t) + 0.5⋅C_{f}   ⋅D_{disk}
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                                         ⎛
#                                         ⎜
#                                         ⎜
#                                    0.5⎞ ⎜
#  ⎛                           2    ⎞   ⎟ ⎜
#  ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟ ⎜  C_{f}⋅K_T⋅S_{w}⋅\eta_{Trans}⋅k_{Pro
# ⋅⎜────────────────────────────────⎟   ⎟⋅⎜- ───────────────────────────────────
#  ⎝              \pi               ⎠   ⎠ ⎜
#                                         ⎜                                    ⎛
#                                         ⎜                                    ⎜
#                                         ⎜                     D_{disk} + 2.0⋅⎜
#                                         ⎜                                    ⎝
#                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#
#
#
#
# 3.5    -0.5      1.0             1.0             -0.5           -1.0
#    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Prop,T}    ⋅k_{Trans}
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#               4
# p,T}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t)            1.0
# ─────────────────────────────────────────────────────── + 0.5⋅C_{f}   ⋅D_{disk
#                                  0.5
#                            2    ⎞
# C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟
# ────────────────────────────────⎟
#               \pi               ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#     ⎛
#     ⎜                                                                       3
#     ⎜                                                     4 ⎛             2⎞
#     ⎜0.0740740740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A + K_T ⎠ ⋅
# 4.0 ⎜
#    ⋅⎜─────────────────────────────────────────────────────────────────────────
#     ⎜
#     ⎜
#     ⎜
#     ⎜
#     ⎜
#     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                ⎛                           2
#                                                ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\
#                                 D_{disk} + 2.0⋅⎜──────────────────────────────
#                                                ⎝              \pi
#
#
#
#                                                                      ⎛
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜0.074074
#  -3.5    -0.5      1.0             1.0             -0.5          4.0 ⎜
# }    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Trans}   ⋅⎜────────
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                                                              ⎛
#                                                              ⎜               ⎛
#                          7    2                            2 ⎜               ⎜
# \eta_{Prop}(t) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{disk} + ⎜
#                                                              ⎝               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                              3
#        ⎛                                                 0.5⎞
#        ⎜               ⎛                           2    ⎞   ⎟
#        ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
#        ⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟
#        ⎝               ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#    0.5
#   ⎞
# pi⎟
# ──⎟
#   ⎠
#
#
#
#
#                                                                3
#                                              4 ⎛             2⎞
# 0740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A + K_T ⎠ ⋅\eta_{Prop}(t
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                         ⎛
#                                                                         ⎜
#                                                                         ⎜
#                                                                         ⎜0.5⋅D
#                                                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                                                  0.5
#                                  0.5⎞                           ⎞
#                            2    ⎞   ⎟                           ⎟
# C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟    ⎛
# ────────────────────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟    ⎜
#               \pi               ⎠   ⎠                           ⎟    ⎜
# ────────────────────────────────────────────────────────────────⎟   ⋅⎜D_{disk}
#                                                                 ⎟    ⎝
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                                 ⎛
#                                                 ⎜               ⎛
#             7    2                            2 ⎜               ⎜C_{f}⋅S_{w} +
# ) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{disk} + ⎜─────────────
#                                                 ⎝               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3
#                                             0.5⎞
#           ⎛                           2    ⎞   ⎟
#           ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# _{disk} + ⎜────────────────────────────────⎟   ⎟
#           ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
# __________________________________________________________________
#
#
#
#                                          0.5⎞
#        ⎛                           2    ⎞   ⎟
#        ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟                 1.0
#  + 2.0⋅⎜────────────────────────────────⎟   ⎟⋅│\eta_{Prop}(t)│
#        ⎝              \pi               ⎠   ⎠
#
#
#                                                                    ⎛
#                                                                    ⎜
#                                                                    ⎜
# ───────────────────────────────────────────────────────────────── ⋅⎜D_{disk} +
#                                                                    ⎝
#
#
#
#
#
#                                                                             2/
#                                                     0.5                    ⎞
#                     0.5⎞                           ⎞                       ⎟
#               2    ⎞   ⎟                           ⎟                       ⎟
#  0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟                       ⎟
# ───────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟                       ⎟
#  \pi               ⎠   ⎠                           ⎟                    1.0⎟
# ───────────────────────────────────────────────────⎟   ⋅│\eta_{Prop}(t)│   ⎟
#                                                    ⎟                       ⎟
#                                                    ⎟                       ⎟
#                                                    ⎟                       ⎟
#                                                    ⎟                       ⎟
#                                                    ⎟                       ⎟
#                                                    ⎠                       ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                        0.5⎞
#      ⎛                           2    ⎞   ⎟
#      ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
#  2.0⋅⎜────────────────────────────────⎟   ⎟
#      ⎝              \pi               ⎠   ⎠
#
#
#
#
#
# 3
#
#
#
#
#
#
#
#
#
#
#
#
#
# ─
#
#
#
#
#
#
#                                                                           4
#                     - 0.419973683298291⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅(0
#
#
#
#
#
#
# \omega_{Motor}(t) = ──────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                  14/3    2/3
#                                                          D_{disk}    ⋅R_A   ⋅\
#
#
#
#
#
#
#
#
#
#
#
#
#                           ⎛             2⎞
# .5 + 0.866025403784439⋅ⅈ)⋅⎝B_M⋅R_A + K_T ⎠⋅\eta_{Prop}(t) + 0.7937005259841⋅D_
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  _____________________________
#                                                 ╱
#                                                ╱
#                                               ╱
#                                              ╱
#                                             ╱
#                                            ╱
#                                           ╱       - C_{f}⋅K_T⋅S_{w}⋅\eta_{Tran
#                                          ╱
#                                         ╱
#                                        ╱
#                                       ╱
#                                      ╱
#            2/3           4/3        ╱
# rho_{water}   ⋅k_{Prop,T}   ⋅      ╱              ────────────────────────────
#                                   ╱
#                                  ╱
#                                 ╱
#                              3 ╱
#                              ╲╱
#
#
#
#
#
#                                                                ⎛
#                                                                ⎜
#       7/3 3 _____ 3 ______________                             ⎜
# {disk}   ⋅╲╱ R_A ⋅╲╱ \rho_{water} ⋅(0.5 - 0.866025403784439⋅ⅈ)⋅⎜D_{disk} + 2.0
#                                                                ⎝
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#
#
#
#
#             4                                                    1.0         -
# s}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t) + 0.5⋅C_{f}   ⋅D_{disk}
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#                                         ⎛
#                                         ⎜
#                                         ⎜
#                                    0.5⎞ ⎜
#  ⎛                           2    ⎞   ⎟ ⎜
#  ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟ ⎜  C_{f}⋅K_T⋅S_{w}⋅\eta_{Trans}⋅k_{Pro
# ⋅⎜────────────────────────────────⎟   ⎟⋅⎜- ───────────────────────────────────
#  ⎝              \pi               ⎠   ⎠ ⎜
#                                         ⎜                                    ⎛
#                                         ⎜                                    ⎜
#                                         ⎜                     D_{disk} + 2.0⋅⎜
#                                         ⎜                                    ⎝
#                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#
#
#
#
# 3.5    -0.5      1.0             1.0             -0.5           -1.0
#    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Prop,T}    ⋅k_{Trans}
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#               4
# p,T}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t)            1.0
# ─────────────────────────────────────────────────────── + 0.5⋅C_{f}   ⋅D_{disk
#                                  0.5
#                            2    ⎞
# C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟
# ────────────────────────────────⎟
#               \pi               ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#     ⎛
#     ⎜                                                                       3
#     ⎜                                                     4 ⎛             2⎞
#     ⎜0.0740740740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A + K_T ⎠ ⋅
# 4.0 ⎜
#    ⋅⎜─────────────────────────────────────────────────────────────────────────
#     ⎜
#     ⎜
#     ⎜
#     ⎜
#     ⎜
#     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                ⎛                           2
#                                                ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\
#                                 D_{disk} + 2.0⋅⎜──────────────────────────────
#                                                ⎝              \pi
#
#
#
#                                                                      ⎛
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜0.074074
#  -3.5    -0.5      1.0             1.0             -0.5          4.0 ⎜
# }    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Trans}   ⋅⎜────────
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎜
#                                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                                                              ⎛
#                                                              ⎜               ⎛
#                          7    2                            2 ⎜               ⎜
# \eta_{Prop}(t) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{disk} + ⎜
#                                                              ⎝               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                              3
#        ⎛                                                 0.5⎞
#        ⎜               ⎛                           2    ⎞   ⎟
#        ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
#        ⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟
#        ⎝               ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#    0.5
#   ⎞
# pi⎟
# ──⎟
#   ⎠
#
#
#
#
#                                                                3
#                                              4 ⎛             2⎞
# 0740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A + K_T ⎠ ⋅\eta_{Prop}(t
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                         ⎛
#                                                                         ⎜
#                                                                         ⎜
#                                                                         ⎜0.5⋅D
#                                                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                                                  0.5
#                                  0.5⎞                           ⎞
#                            2    ⎞   ⎟                           ⎟
# C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟    ⎛
# ────────────────────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟    ⎜
#               \pi               ⎠   ⎠                           ⎟    ⎜
# ────────────────────────────────────────────────────────────────⎟   ⋅⎜D_{disk}
#                                                                 ⎟    ⎝
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎟
#                                                                 ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                                 ⎛
#                                                 ⎜               ⎛
#             7    2                            2 ⎜               ⎜C_{f}⋅S_{w} +
# ) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{disk} + ⎜─────────────
#                                                 ⎝               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3
#                                             0.5⎞
#           ⎛                           2    ⎞   ⎟
#           ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# _{disk} + ⎜────────────────────────────────⎟   ⎟
#           ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
# __________________________________________________________________
#
#
#
#                                          0.5⎞
#        ⎛                           2    ⎞   ⎟
# ...
#                                                              ⎜
#                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#
#
#
#
#          -3.5    -0.5      1.0             1.0             -0.5           -1.0
# ⋅D_{disk}    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Prop,T}
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                    4
# }⋅\eta_{Trans}⋅k_{Prop,T}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t)
# ──────────────────────────────────────────────────────────────────────────── +
#                                                       0.5
#                     ⎛                           2    ⎞
#                     ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟
#      D_{disk} + 2.0⋅⎜────────────────────────────────⎟
#                     ⎝              \pi               ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#               ⎛
#               ⎜
#               ⎜                                                     4 ⎛
#               ⎜0.0740740740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A
#           4.0 ⎜
# ⋅k_{Trans}   ⋅⎜───────────────────────────────────────────────────────────────
#               ⎜
#               ⎜
#               ⎜
#               ⎜
#               ⎜
#               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                          ⎛
#                                                          ⎜C_{f}⋅S_{w} + 0.25⋅D
#                                           D_{disk} + 2.0⋅⎜────────────────────
#                                                          ⎝              \pi
#
#
#
#
#
#
#
#           1.0         -3.5    -0.5      1.0             1.0             -0.5
#  0.5⋅C_{f}   ⋅D_{disk}    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                                                                        ⎛
#         3                                                              ⎜
#       2⎞                           7    2                            2 ⎜
#  + K_T ⎠ ⋅\eta_{Prop}(t) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_
#                                                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        3
#                  ⎛                                                 0.5⎞
#                  ⎜               ⎛                           2    ⎞   ⎟
#                  ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
#                  ⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟
#                  ⎝               ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#              0.5
#        2    ⎞
# _{disk} ⋅\pi⎟
# ────────────⎟
#             ⎠
#
#
#
#             ⎛
#             ⎜
#             ⎜                                                     4 ⎛
#             ⎜0.0740740740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A +
#         4.0 ⎜
# _{Trans}   ⋅⎜─────────────────────────────────────────────────────────────────
#             ⎜
#             ⎜
#             ⎜
#             ⎜
#             ⎜
#             ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                                                            0.5
#                                            0.5⎞                           ⎞
#          ⎛                           2    ⎞   ⎟                           ⎟
#          ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟
# {disk} + ⎜────────────────────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟
#          ⎝              \pi               ⎠   ⎠                           ⎟
# ──────────────────────────────────────────────────────────────────────────⎟
#                                                                           ⎟
#                                                                           ⎟
#                                                                           ⎟
#                                                                           ⎟
#                                                                           ⎟
#                                                                           ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                                                      ⎛
#       3                                                              ⎜
#     2⎞                           7    2                            2 ⎜
#  K_T ⎠ ⋅\eta_{Prop}(t) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{d
#                                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      3
#                ⎛                                                 0.5⎞
#                ⎜               ⎛                           2    ⎞   ⎟
#                ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
#                ⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟
#                ⎝               ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ____________________________________________________________________________
#
#
#
#  ⎛                                                 0.5⎞
#  ⎜               ⎛                           2    ⎞   ⎟
#  ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟                 1.0
# ⋅⎜D_{disk} + 2.0⋅⎜────────────────────────────────⎟   ⎟⋅│\eta_{Prop}(t)│
#  ⎝               ⎝              \pi               ⎠   ⎠
#
#
#                                                                              ⎛
#                                                                              ⎜
#                                                                              ⎜
# ─────────────────────────────────────────────────────────────────────────── ⋅⎜
#                                                                              ⎝
#
#
#
#
#
#
#                                                                          0.5
#                                          0.5⎞                           ⎞
#        ⎛                           2    ⎞   ⎟                           ⎟
#        ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟
# isk} + ⎜────────────────────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟
#        ⎝              \pi               ⎠   ⎠                           ⎟
# ────────────────────────────────────────────────────────────────────────⎟   ⋅│
#                                                                         ⎟
#                                                                         ⎟
#                                                                         ⎟
#                                                                         ⎟
#                                                                         ⎟
#                                                                         ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                                  0.5⎞
#                ⎛                           2    ⎞   ⎟
#                ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# D_{disk} + 2.0⋅⎜────────────────────────────────⎟   ⎟
#                ⎝              \pi               ⎠   ⎠
#
#
#
#
#
#                    2/3
#                   ⎞
#                   ⎟
#                   ⎟
#                   ⎟
#                   ⎟
#                1.0⎟
# \eta_{Prop}(t)│   ⎟
#                   ⎟
#                   ⎟
#                   ⎟
#                   ⎟
#                   ⎟
#                   ⎠
# ──────────────────────

# %%
eq_esc_pi3 = eq_esc_pi2.subs({eq_motor_w_ss2.lhs: eq_motor_w_ss2.rhs})
display(eq_esc_pi3)
# Out:
#
#                                                                            ⎛
#                                                                            ⎜
#                                                                            ⎜
#                                                                            ⎜
#                        ⎛                _________________________________⎞ ⎜
#                        ⎜               ╱                           2     ⎟ ⎜
#                        ⎜              ╱  4.0⋅C_{f}⋅S_{w} + D_{disk} ⋅\pi ⎟ ⎜
#                 0.0625⋅⎜D_{disk} +   ╱   ─────────────────────────────── ⎟⋅⎜0.
#                        ⎝           ╲╱                  \pi               ⎠ ⎜
#                                                                            ⎜
#                                                                            ⎜
#                                                                            ⎜
#                                                                            ⎜
#                                                                            ⎝
# P_{ESC,in}(t) = ──────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                            35/
#                                                              C_{f}⋅D_{disk}
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                           4
# 419973683298291⋅B_M⋅C_{f}⋅R_A⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t) + 0
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                       ⎛
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜- C_{f}
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
# 3    8/3                                5/3           10/3          4 ⎜
#  ⋅R_A   ⋅S_{w}⋅\eta_{Trans}⋅\rho_{water}   ⋅k_{Prop,T}    ⋅k_{Trans} ⋅⎜───────
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎜
#                                                                       ⎝
#
#
#
#
#
#
#
#
#                           2                             4
# .419973683298291⋅C_{f}⋅K_T ⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅\eta_{Prop}(t) - D_{
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                  4
# ⋅K_T⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t) + 0
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                   ⎛
#                                   ⎜
#      7/3 3 _____ 3 ______________ ⎜
# disk}   ⋅╲╱ R_A ⋅╲╱ \rho_{water} ⋅⎜0.7937005259841⋅D_{disk} + 1.5874010519682⋅
#                                   ⎝
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#         1.0         -3.5    -0.5      1.0             1.0             -0.5
# .5⋅C_{f}   ⋅D_{disk}    ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                        ⎛
#                                        ⎜
#                                        ⎜
#                                   0.5⎞ ⎜
# ⎛                           2    ⎞   ⎟ ⎜
# ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟ ⎜  C_{f}⋅K_T⋅S_{w}⋅\eta_{Trans}⋅k_{Prop
# ⎜────────────────────────────────⎟   ⎟⋅⎜- ────────────────────────────────────
# ⎝              \pi               ⎠   ⎠ ⎜
#                                        ⎜                                    ⎛
#                                        ⎜                                    ⎜C
#                                        ⎜                     D_{disk} + 2.0⋅⎜─
#                                        ⎜                                    ⎝
#                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                          ⎛
#                          ⎜
#                          ⎜
#                          ⎜0.0740740740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans
#        -1.0          4.0 ⎜
# Prop,T}    ⋅k_{Trans}   ⋅⎜────────────────────────────────────────────────────
#                          ⎜
#                          ⎜
#                          ⎜
#                          ⎜
#                          ⎜
#                          ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                     ⎛
#                                                                     ⎜C_{f}⋅S_{
#                                                      D_{disk} + 2.0⋅⎜─────────
#                                                                     ⎝
#
#
#
#
#
#
#
#              4
# ,T}⋅k_{Trans} ⋅D_{ESC}(t)⋅V_{ESC,in}(t)⋅\eta_{Prop}(t)            1.0
# ────────────────────────────────────────────────────── + 0.5⋅C_{f}   ⋅D_{disk}
#                                 0.5
#                           2    ⎞
# _{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟
# ───────────────────────────────⎟
#              \pi               ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    3
#  4 ⎛             2⎞                           7    2
# } ⋅⎝B_M⋅R_A + K_T ⎠ ⋅\eta_{Prop}(t) + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                             ⎛
#                             ⎜               ⎛                           2    ⎞
#                             ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟
#                             ⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟
#                             ⎝               ⎝              \pi               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                         0.5
#                   2    ⎞
# w} + 0.25⋅D_{disk} ⋅\pi⎟
# ───────────────────────⎟
#      \pi               ⎠
#
#
#
#
#                                                                     ⎛
#                                                                     ⎜
#                                                                     ⎜
#                                                                     ⎜0.0740740
# -3.5    -0.5      1.0             1.0             -0.5          4.0 ⎜
#     ⋅R_A    ⋅S_{w}   ⋅\eta_{Trans}   ⋅\rho_{water}    ⋅k_{Trans}   ⋅⎜─────────
#                                                                     ⎜
#                                                                     ⎜
#                                                                     ⎜
#                                                                     ⎜
#                                                                     ⎜
#                                                                     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     ⎛                                                 0.5⎞
#     ⎜               ⎛                           2    ⎞   ⎟
#   2 ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2
# T} ⋅⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,
#     ⎝               ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#     3
# 0.5⎞
#    ⎟
#    ⎟
#    ⎟
#    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                                               3
#                                             4 ⎛             2⎞
# 740740741⋅C_{f}⋅S_{w}⋅\eta_{Trans}⋅k_{Trans} ⋅⎝B_M⋅R_A + K_T ⎠ ⋅\eta_{Prop}(t)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                        ⎛
#                                                                        ⎜
#                                                                        ⎜
#                                                                        ⎜0.5⋅D_
#                                                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#         0.5
#        ⎞
#        ⎟
#    2   ⎟    ⎛                                                 0.5⎞
# in} (t)⎟    ⎜               ⎛                           2    ⎞   ⎟
#        ⎟    ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# ───────⎟   ⋅⎜D_{disk} + 2.0⋅⎜────────────────────────────────⎟   ⎟⋅│\eta_{Prop
#        ⎟    ⎝               ⎝              \pi               ⎠   ⎠
#        ⎟
#        ⎟
#        ⎟
#        ⎟
#        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#                                                ⎛
#                                                ⎜               ⎛
#            7    2                            2 ⎜               ⎜C_{f}⋅S_{w} +
#  + D_{disk} ⋅K_T ⋅R_A⋅\rho_{water}⋅k_{Prop,T} ⋅⎜0.5⋅D_{disk} + ⎜──────────────
#                                                ⎝               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                3
#                                            0.5⎞
#          ⎛                           2    ⎞   ⎟
#          ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# {disk} + ⎜────────────────────────────────⎟   ⎟
#          ⎝              \pi               ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#          4/3
#         ⎞
#         ⎟
#         ⎟
#         ⎟
#         ⎟
#      1.0⎟
# }(t)│   ⎟
#         ⎟
#         ⎟
#         ⎟                                                          4
#         ⎟    ⎛                                                 0.5⎞
#         ⎟    ⎜               ⎛                           2    ⎞   ⎟
#         ⎟    ⎜               ⎜C_{f}⋅S_{w} + 0.25⋅D_{disk} ⋅\pi⎟   ⎟
# ────────⎟   ⋅⎜0.5⋅D_{disk} + ⎜────────────────────────────────⎟   ⎟ ⋅\eta_{ESC
#         ⎟    ⎝               ⎝              \pi               ⎠   ⎠
#         ⎟
#         ⎟
#         ⎟
#         ⎠
#
#
#                                                                            2/3
#                                                    0.5                    ⎞
#                    0.5⎞                           ⎞                       ⎟
#              2    ⎞   ⎟                           ⎟                       ⎟
# 0.25⋅D_{disk} ⋅\pi⎟   ⎟        2              2   ⎟                       ⎟
# ──────────────────⎟   ⎟⋅D_{ESC} (t)⋅V_{ESC,in} (t)⎟                       ⎟
# \pi               ⎠   ⎠                           ⎟                    1.0⎟
# ──────────────────────────────────────────────────⎟   ⋅│\eta_{Prop}(t)│   ⎟
#                                                   ⎟                       ⎟
#                                                   ⎟                       ⎟
#                                                   ⎟                       ⎟
#                                                   ⎟                       ⎟
#                                                   ⎟                       ⎟
#                                                   ⎠                       ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# }(t)⋅\eta_{Motor}(t)⋅\eta_{Prop}(t)
#
#
#
#
#
#
#  4
# ⎞
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎠
# ──

# %%
symbols = {
    "P_{Prop,in}": 'prop_pi',
    "P_{Prop,out}": 'prop_po',
    "Q_{Prop}": 'prop_Q',
    "T_{Prop}": 'prop_T',
    "\\omega_{Prop}": 'prop_w',
    "V_{Prop}": 'prop_V',
    "J_{prop}": 'prop_J',
    "\\eta_{Prop}": 'prop_eff',
    "V_{hull}": 'hull_V',
    "R_{Hull}": 'hull_R',
    "Q_{Trans, in}": 'trans_Qi',
    "Q_{Trans, out}": 'trans_Qo',
    "\\omega_{Trans, in}": 'trans_wi',
    "\\omega_{Trans, out}": 'trans_wo',
    "P_{Trans, in}": 'trans_pi',
    "P_{Trans, out}": 'trans_po',
    "I_{Motor}": 'motor_i',
    "V_{Motor}": 'motor_v',
    "\\omega_{Motor}": 'motor_w',
    "\\theta_{Motor}": 'motor_ang',
    "Q_{Motor Load}": 'motor_load_Q',
    "P_{Motor,in}": 'motor_pi',
    "P_{Motor,out}": 'motor_po',
    "P_{Motor,loss}": 'motor_pl',
    "\\eta_{Motor}": 'motor_eff',
    "D_{ESC}": 'esc_D',
    "P_{ESC,in}": 'esc_pi',
    "P_{ESC,out}": 'esc_po',
    "V_{ESC,in}": 'esc_vi',
    "V_{ESC,out}": 'esc_vo',
    "I_{ESC,in}": 'esc_ii',
    "I_{ESC,out}": 'esc_io',
    "\\eta_{ESC}": 'esc_eff',
    "\\rho_{water}": 'rho',
    "D_{disc}": 'prop_D',
    "A_{disc}": 'prop_A',
    "k_{Prop,T}": 'prop_kT',
    "k_{Prop,Q}": 'prop_kQ',
    'D_{disk}': 'prop_D',
    "k_{Hull}": "hull_k",
    "C_{f}": "hull_S",
    "S_{w}": "hull_C",
    "k_{Trans}": "trans_K",
    "\\eta_{Trans}": "trans_eff",
    "R_A": "motor_R",
    "L_A": "motor_L",
    "K_T": "motor_K",
    "K_V": "motor_K",
    "J_M": "motor_J",
    "B_M": "motor_B",
    "\\pi": "pi",
    "(t)": '',
}

def sym_to_python(expr, symbols):
    expr = sym.python(expr).split('\n')[-1]
    for k,v in symbols.items():
        expr = expr.replace(k,v)
    return expr


sym_to_python(eq_esc_pi3.rhs, symbols)
# Out:
# 'e = 0.0625*(prop_D + sqrt((4.0*hull_S*hull_C + prop_D**2*pi)/pi))*(0.419973683298291*motor_B*hull_S*motor_R*hull_C*trans_eff*trans_K**4*prop_eff + 0.419973683298291*hull_S*motor_K**2*hull_C*trans_eff*trans_K**4*prop_eff - prop_D**(7/3)*motor_R**(1/3)*rho**(1/3)*(0.7937005259841*prop_D + 1.5874010519682*((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)*(-hull_S*motor_K*hull_C*trans_eff*prop_kT*trans_K**4*esc_D*esc_vi*prop_eff/(prop_D + 2.0*((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5) + 0.5*hull_S**1.0*hull_C**1.0*trans_eff**1.0*trans_K**4.0*((0.0740740740740741*hull_S*hull_C*trans_eff*trans_K**4*(motor_B*motor_R + motor_K**2)**3*prop_eff + prop_D**7*motor_K**2*motor_R*rho*prop_kT**2*(0.5*prop_D + ((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)*esc_D**2*esc_vi**2)/(0.5*prop_D + ((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)**3)**0.5*Abs(prop_eff)**1.0/(prop_D**3.5*motor_R**0.5*rho**0.5))**(2/3))**4/(hull_S*prop_D**(35/3)*motor_R**(8/3)*hull_C*trans_eff*rho**(5/3)*prop_kT**(10/3)*trans_K**4*((-hull_S*motor_K*hull_C*trans_eff*trans_K**4*esc_D*esc_vi*prop_eff + 0.5*hull_S**1.0*hull_C**1.0*trans_eff**1.0*trans_K**4.0*((0.0740740740740741*hull_S*hull_C*trans_eff*trans_K**4*(motor_B*motor_R + motor_K**2)**3*prop_eff + prop_D**7*motor_K**2*motor_R*rho*prop_kT**2*(0.5*prop_D + ((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)*esc_D**2*esc_vi**2)/(0.5*prop_D + ((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)**3)**0.5*(prop_D + 2.0*((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)*Abs(prop_eff)**1.0/(prop_D**3.5*motor_R**0.5*rho**0.5*prop_kT**1.0))/(prop_D + 2.0*((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5))**(4/3)*(0.5*prop_D + ((hull_S*hull_C + 0.25*prop_D**2*pi)/pi)**0.5)**4*esc_eff*motor_eff*prop_eff)'

# %%
print(sym_to_python(eq_motor_load_Q.rhs, symbols).replace('e =', 'motor_load_Q ='))
print(sym_to_python(eq_motor_dwdt.rhs, symbols).replace('e =', 'dwdt ='))
print(sym_to_python(eq_motor_didt.rhs, symbols).replace('e =', 'didt ='))
# Out:
# motor_load_Q = prop_D**7*rho*prop_kT**2*(prop_D + sqrt((4.0*hull_S*hull_C + prop_D**2*pi)/pi))*motor_w**3/(hull_S*hull_C*trans_eff*trans_K**4*prop_eff)
# dwdt = -motor_B*motor_w/motor_J + motor_K*motor_i/motor_J - motor_load_Q/motor_J
# didt = -motor_K*motor_w/motor_L - motor_R*motor_i/motor_L + motor_v/motor_L
